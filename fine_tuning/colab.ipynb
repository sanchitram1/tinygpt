# %% [markdown]
# # Colab Runner

# %% [markdown]
# This notebook is just a placeholder for running fine_tune.py on a colab server

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
if device.type == "cuda":
    print(torch.cuda.get_device_name(0))
# Out:
# cuda
# Tesla T4

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/sanchitram1/242b-hw3
# %cd 242b-hw3
# Out:
# Cloning into '242b-hw3'...
# remote: Enumerating objects: 186, done.
# remote: Counting objects: 100% (186/186), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 186 (delta 109), reused 133 (delta 56), pack-reused 0 (from 0)
# Receiving objects: 100% (186/186), 2.40 MiB | 24.33 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# /content/242b-hw3

# %%
from config import DataConfig, RunConfig


data_config = DataConfig()
run_config = RunConfig("xlarge-lora-steps=500_000")
# Out:
# Created /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-steps=500_000 and subfolders

# %%
instruction_path = "/content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-merged-train.txt"
validation_path = "/content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-templates-valid.txt"
model_path = run_config.models / "xlarge-pretrained.pt"

print(instruction_path)
print(validation_path)
print(model_path)
# Out:
# /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-merged-train.txt
# /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-templates-valid.txt
# /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-steps=500_000/models/xlarge-pretrained.pt

# %%
# !PYTHONPATH=. python fine_tuning/fine_tune_v2.py {model_path} --instruction-training-file {instruction_path} --instruction-validation-file {validation_path} --run-id {run_config.run_id} --device cuda --batch-size 16 --max-steps 3000 --rank 32 --alpha 64 --learning-rate 2e-4 --target-ff
# Out:
# Training on: Tesla T4
# Found it in /content/drive/MyDrive/courses/242B/HW3/artifacts/shared/tokenizers/tinystories_bpe_metaspace_5000_1000000.json, loading from there
# Loading training data from /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-merged-train.txt ...
#   -> 10000 complete instruction pairs
# Loading validation data from /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-templates-valid.txt ...
#   -> 200 complete instruction pairs
# Model: 2,359,296 total params, 2,359,296 trainable (LoRA rank=32)
# Directory already exists: /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-steps=500_000
# [xlarge-lora-v2] step=    1 train_loss=12.0666 train_ppl=173969.807 valid_loss=12.3639 valid_ppl=234204.461 *BEST*
# [xlarge-lora-v2] step=  200 train_loss=0.0587 train_ppl=1.060 valid_loss=0.0370 valid_ppl=1.038 *BEST*
# [xlarge-lora-v2] step=  400 train_loss=0.0102 train_ppl=1.010 valid_loss=0.0087 valid_ppl=1.009 *BEST*
# ...
