# %% [markdown]
# # Colab Runner

# %% [markdown]
# This notebook is just a placeholder for running fine_tune.py on a colab server

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
if device.type == "cuda":
    print(torch.cuda.get_device_name(0))
# Out:
# cuda
# Tesla T4

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/sanchitram1/242b-hw3
# %cd 242b-hw3
# Out:
# Cloning into '242b-hw3'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 175 (delta 105), reused 123 (delta 53), pack-reused 0 (from 0)
# Receiving objects: 100% (175/175), 2.39 MiB | 22.23 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# /content/242b-hw3

# %%
from config import DataConfig, RunConfig


data_config = DataConfig()
run_config = RunConfig("xlarge-lora-data=500-steps=1000")
# Out:
# Created /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-data=500-steps=1000 and subfolders
# /content/drive/MyDrive/courses/242B/HW3/fine_tuning-instructions-train.txt /content/drive/MyDrive/courses/242B/HW3/fine_tuning-instructions-valid.txt

# %%
print(data_config.instruction_training_file)
print(data_config.instruction_validation_file)
print(run_config.models / "xlarge-pretrained.pt")
# Out:
# /content/drive/MyDrive/courses/242B/HW3/fine_tuning-instructions-train.txt
# /content/drive/MyDrive/courses/242B/HW3/fine_tuning-instructions-valid.txt
# /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-data=500-steps=1000/models/xlarge-pretrained.pt

# %%
instruction_path = data_config.instruction_training_file
validation_path = data_config.instruction_validation_file
model_path = run_config.models / "xlarge-pretrained.pt"

# !PYTHONPATH=. python fine_tuning/fine_tune.py {model_path} --instruction-training-file {instruction_path} --instruction-validation-file {validation_path} --run-id {run_config.run_id} --device cuda --learning-rate 0.00005 --max-steps 1000
# Out:
# Found it in /content/drive/MyDrive/courses/242B/HW3/artifacts/shared/tokenizers/tinystories_bpe_metaspace_5000_1000000.json, loading from there
# Found it in /content/drive/MyDrive/courses/242B/HW3/artifacts/shared/tokenizers/tinystories_bpe_metaspace_5000_1000000.json, loading from there
# Directory already exists: /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-data=500-steps=1000
# [xlarge-lora] step=1 train_loss=nan train_ppl=nan valid_loss=nan valid_ppl=nan
# [xlarge-lora] step=100 train_loss=nan train_ppl=nan valid_loss=nan valid_ppl=nan
# [xlarge-lora] step=200 train_loss=1.3180 train_ppl=3.736 valid_loss=nan valid_ppl=nan
# [xlarge-lora] step=300 train_loss=nan train_ppl=nan valid_loss=nan valid_ppl=nan
# [xlarge-lora] step=400 train_loss=nan train_ppl=nan valid_loss=nan valid_ppl=nan
# [xlarge-lora] step=500 train_loss=1.1144 train_ppl=3.048 valid_loss=nan valid_ppl=nan
# [xlarge-lora] step=600 train_loss=nan train_ppl=nan valid_loss=nan valid_ppl=nan
# ...

# %%
# !PYTHONPATH=. python fine_tuning/fine_tune.py run_config.models / "xlarge-pretrained.pt" --instruction-training-file data_config.instruction_training_file
# Out:
# usage: fine_tune.py [-h] --instruction-training-file INSTRUCTION_TRAINING_FILE
#                     --instruction-validation-file INSTRUCTION_VALIDATION_FILE
#                     [--run-id RUN_ID] [--device {auto,cuda,cpu}]
#                     [--batch-size BATCH_SIZE] [--learning-rate LEARNING_RATE]
#                     [--weight-decay WEIGHT_DECAY]
#                     [--warmup-steps WARMUP_STEPS] [--max-steps MAX_STEPS]
#                     [--checkpoint-every CHECKPOINT_EVERY]
#                     [--max-train-stories MAX_TRAIN_STORIES] [--rank RANK]
#                     [--alpha ALPHA] [--lora-dropout LORA_DROPOUT]
#                     [--target-ff] [--no-amp]
#                     pretrained_model
#
# LoRA fine-tune a pretrained TinyGPT checkpoint on instructions.
#
# positional arguments:
#   pretrained_model      Path to the pretrained TinyGPT checkpoint.
#
# options:
#   -h, --help            show this help message and exit
# ...
