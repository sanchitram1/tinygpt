# %% [markdown]
# # Colab Runner

# %% [markdown]
# This notebook is just a placeholder for running fine_tune.py on a colab server

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
if device.type == "cuda":
    print(torch.cuda.get_device_name(0))
# Out:
# cuda
# Tesla T4

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %rm -rf 242b-hw3

# %%
# !git clone https://github.com/sanchitram1/242b-hw3
# %cd 242b-hw3
# Out:
# Cloning into '242b-hw3'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 192 (delta 113), reused 137 (delta 58), pack-reused 0 (from 0)
# Receiving objects: 100% (192/192), 2.41 MiB | 23.03 MiB/s, done.
# Resolving deltas: 100% (113/113), done.
# /content/242b-hw3

# %%
from config import DataConfig, RunConfig


data_config = DataConfig()
run_config = RunConfig("xlarge-lora-v3")
# Out:
# Created /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-v3 and subfolders

# %%
instruction_path = "/content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-merged-train.txt"
validation_path = "/content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-templates-valid.txt"
model_path = run_config.models / "xlarge-pretrained.pt"

print(instruction_path)
print(validation_path)
print(model_path)
# Out:
# /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-merged-train.txt
# /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-templates-valid.txt
# /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-v3/models/xlarge-pretrained.pt

# %%
# !PYTHONPATH=. python fine_tuning/fine_tune_v2.py {model_path} --instruction-training-file {instruction_path} --instruction-validation-file {validation_path} --run-id {run_config.run_id} --device cuda --batch-size 8 --learning-rate 5e-5 --max-steps 500 --rank 8 --alpha 8
# Out:
# Training on: Tesla T4
# Found it in /content/drive/MyDrive/courses/242B/HW3/artifacts/shared/tokenizers/tinystories_bpe_metaspace_5000_1000000.json, loading from there
# Loading training data from /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-merged-train.txt ...
#   -> 10500 complete instruction pairs
# Loading validation data from /content/drive/MyDrive/courses/242B/HW3/data/fine_tuning-instructions-templates-valid.txt ...
#   -> 200 complete instruction pairs
# Model: 221,184 total params, 221,184 trainable (LoRA rank=8)
# Directory already exists: /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-v3
# [xlarge-plus-lora-v2] step=    1 train_loss=11.5119 train_ppl=99896.072 valid_loss=11.5644 valid_ppl=105280.067 *BEST*
# [xlarge-plus-lora-v2] step=  200 train_loss=9.3700 train_ppl=11730.957 valid_loss=9.4632 valid_ppl=12877.293 *BEST*
# [xlarge-plus-lora-v2] step=  400 train_loss=6.0589 train_ppl=427.901 valid_loss=6.2337 valid_ppl=509.651 *BEST*
# Saved model to /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-v3/models/xlarge-plus-lora-v2.pt
# Saved metrics to /content/drive/MyDrive/courses/242B/HW3/artifacts/runs/xlarge-lora-v3/metrics/xlarge-plus-lora-v2.json
# Done! 11s, 379,780 tokens, best valid loss: 6.2337
